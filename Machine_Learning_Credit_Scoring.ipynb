# %% [markdown]
# <a href="https://colab.research.google.com/github/annaguassu/Algoritmos-e-Logica-da-Programacao/blob/main/Machine_Learning_Credit_Scoring.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/credit_scoring/main/base_dados_traduzida.csv'
dados = pd.read_csv(url)

dados.head()
# Out:
#    default       conta_corrente  prazo_emprestimo_meses  \
# 0        0               < 0 DM                       6
# 1        1    0 <= ... < 200 DM                      48
# 2        0  no checking account                      12
# 3        0               < 0 DM                      42
# 4        1               < 0 DM                      24
#
#                                    historico_credito  \
# 0  critical account/ other credits existing (not ...
# 1           existing credits paid back duly till now
# 2  critical account/ other credits existing (not ...
# 3           existing credits paid back duly till now
# 4                    delay in paying off in the past
#
#            proposito_emprestimo  valor_emprestimo  \
# 0           domestic appliances              1169
# 1           domestic appliances              5951
# 2  (vacation - does not exist?)              2096
# 3              radio/television              7882
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   default                      1000 non-null   int64
#  1   conta_corrente               1000 non-null   object
#  2   prazo_emprestimo_meses       1000 non-null   int64
#  3   historico_credito            1000 non-null   object
#  4   proposito_emprestimo         1000 non-null   object
#  5   valor_emprestimo             1000 non-null   int64
#  6   reserva_cc                   1000 non-null   object
#  7   tempo_emprego_atual          1000 non-null   object
#  8   taxa_comp_salario            1000 non-null   int64
#  9   sexo_est_civil               1000 non-null   object
#  10  outros_fiadores              1000 non-null   object
#  11  anos_residencia_atual        1000 non-null   int64
#  12  propriedade                  1000 non-null   object
# ...

# %%
linhas = dados.shape[0]
colunas = dados.shape[1]

print('A base de dados tem %s linhas e %s colunas.'%(linhas, colunas))
# Out:
# A base de dados tem 1000 linhas e 21 colunas.

# %%
duplicados = dados.duplicated()
duplicados = duplicados.sum()

print('A base de dados tem %s tem dados duplicados.' %(duplicados))
# Out:
# A base de dados tem 0 tem dados duplicados.

# %%
nulos = dados.isnull()
nulos.sum()
# Out:
# default                        0
# conta_corrente                 0
# prazo_emprestimo_meses         0
# historico_credito              0
# proposito_emprestimo           0
# valor_emprestimo               0
# reserva_cc                     0
# tempo_emprego_atual            0
# taxa_comp_salario              0
# sexo_est_civil                 0
# outros_fiadores                0
# anos_residencia_atual          0
# propriedade                    0
# idade                          0
# outros_planos_financiamento    0
# tipo_residencia                0
# n_creditos_banco               0
# status_emprego                 0
# n_dependentes                  0
# telefone                       0
# trabalhador_estrangeiro        0
# dtype: int64

# %%
dados.head()
# Out:
#    default       conta_corrente  prazo_emprestimo_meses  \
# 0        0               < 0 DM                       6
# 1        1    0 <= ... < 200 DM                      48
# 2        0  no checking account                      12
# 3        0               < 0 DM                      42
# 4        1               < 0 DM                      24
#
#                                    historico_credito  \
# 0  critical account/ other credits existing (not ...
# 1           existing credits paid back duly till now
# 2  critical account/ other credits existing (not ...
# 3           existing credits paid back duly till now
# 4                    delay in paying off in the past
#
#            proposito_emprestimo  valor_emprestimo  \
# 0           domestic appliances              1169
# 1           domestic appliances              5951
# 2  (vacation - does not exist?)              2096
# 3              radio/television              7882
# ...

# %%
y = dados['default']
y.head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    1
# Name: default, dtype: int64

# %%
x = dados.drop(columns = 'default') #a base toda, exceto a default
x.head()
# Out:
#         conta_corrente  prazo_emprestimo_meses  \
# 0               < 0 DM                       6
# 1    0 <= ... < 200 DM                      48
# 2  no checking account                      12
# 3               < 0 DM                      42
# 4               < 0 DM                      24
#
#                                    historico_credito  \
# 0  critical account/ other credits existing (not ...
# 1           existing credits paid back duly till now
# 2  critical account/ other credits existing (not ...
# 3           existing credits paid back duly till now
# 4                    delay in paying off in the past
#
#            proposito_emprestimo  valor_emprestimo  \
# 0           domestic appliances              1169
# 1           domestic appliances              5951
# 2  (vacation - does not exist?)              2096
# 3              radio/television              7882
# 4                     car (new)              4870
#
# ...

# %%
from sklearn.model_selection import train_test_split

SEED = 77
treino_x, teste_x, treino_y, teste_y = train_test_split(x, y, test_size = 0.30, random_state = SEED)

base_treino = treino_x.shape[0] #shape--> tamanho da base em relação as linhas
base_teste = teste_x.shape[0]

print ('A base de treino tem %s elementos e a base de teste tem %s elementos. ' %(base_treino, base_teste))
# Out:
# A base de treino tem 700 elementos e a base de teste tem 300 elementos.

# %%
from sklearn.linear_model import LogisticRegression

modelo = LogisticRegression(max_iter=1000) #a qtd de interações que ele vai fazer
modelo.fit(treino_x, treino_y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-0b291b7c502a> in <cell line: 4>()
#       2
#       3 modelo = LogisticRegression(max_iter=1000) #a qtd de interações que ele vai fazer
# ----> 4 modelo.fit(treino_x, treino_y)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1194             _dtype = [np.float64, np.float32]
#    1195
# -> 1196         X, y = self._validate_data(
#    1197             X,
#    1198             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# --> 584                 X, y = check_X_y(X, y, **check_params)
#     585             out = X, y
#     586
#
# ...

# %%
dados.head()
# Out:
#    default       conta_corrente  prazo_emprestimo_meses  \
# 0        0               < 0 DM                       6
# 1        1    0 <= ... < 200 DM                      48
# 2        0  no checking account                      12
# 3        0               < 0 DM                      42
# 4        1               < 0 DM                      24
#
#                                    historico_credito  \
# 0  critical account/ other credits existing (not ...
# 1           existing credits paid back duly till now
# 2  critical account/ other credits existing (not ...
# 3           existing credits paid back duly till now
# 4                    delay in paying off in the past
#
#            proposito_emprestimo  valor_emprestimo  \
# 0           domestic appliances              1169
# 1           domestic appliances              5951
# 2  (vacation - does not exist?)              2096
# 3              radio/television              7882
# ...

# %%
dados['conta_corrente'].unique()
# Out:
# array(['< 0 DM', '0 <= ... < 200 DM', 'no checking account',
#        '>= 200 DM / salary assignments for at least 1 year'], dtype=object)

# %%
a = {'< 0 DM':1,
     '0 <= ... < 200 DM':2,
     'no checking account':3,
    '>= 200 DM / salary assignments for at least 1 year':4
}

dados['conta_corrente'] = dados['conta_corrente'].map(a)
dados.head()
# Out:
#    default  conta_corrente  prazo_emprestimo_meses  \
# 0        0               1                       6
# 1        1               2                      48
# 2        0               3                      12
# 3        0               1                      42
# 4        1               1                      24
#
#                                    historico_credito  \
# 0  critical account/ other credits existing (not ...
# 1           existing credits paid back duly till now
# 2  critical account/ other credits existing (not ...
# 3           existing credits paid back duly till now
# 4                    delay in paying off in the past
#
#            proposito_emprestimo  valor_emprestimo  \
# 0           domestic appliances              1169
# 1           domestic appliances              5951
# 2  (vacation - does not exist?)              2096
# 3              radio/television              7882
# 4                     car (new)              4870
#
# ...

# %%
y = dados['default']
x = dados.drop(columns = 'default')

SEED = 77
treino_x, teste_x, treino_y, teste_y = train_test_split(x, y, test_size = 0.30, random_state = SEED)

base_treino = treino_x.shape[0] #shape--> tamanho da base em relação as linhas
base_teste = teste_x.shape[0]

print ('A base de treino tem %s elementos e a base de teste tem %s elementos. ' %(base_treino, base_teste))

modelo = LogisticRegression(max_iter=1000) #a qtd de interações que ele vai fazer
modelo.fit(treino_x, treino_y)
print(modelo.score(treino_x, treino_y)) #acuracia
# Out:
# A base de treino tem 700 elementos e a base de teste tem 300 elementos.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-1deb5cc4bc9d> in <cell line: 13>()
#      11
#      12 modelo = LogisticRegression(max_iter=1000) #a qtd de interações que ele vai fazer
# ---> 13 modelo.fit(treino_x, treino_y)
#      14 print(modelo.score(treino_x, treino_y)) #acuracia
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1194             _dtype = [np.float64, np.float32]
#    1195
# -> 1196         X, y = self._validate_data(
#    1197             X,
#    1198             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
# ...
